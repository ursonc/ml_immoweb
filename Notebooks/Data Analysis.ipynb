# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder

# Load the dataset
df = pd.read_csv('houses_sqm.csv')

# Step 1: Display unique values for each column
for column in df.columns:
    print(f'For {column}, {df[column].nunique()} unique values present')

# Step 2: Define a function to plot distributions for categorical variables
def plot_categorical_distributions(df):
    """
    Plots bar charts for each categorical variable in the DataFrame.
    Parameters:
    - df (pd.DataFrame): The input DataFrame with categorical variables.
    Returns:
    - None: Displays bar charts for each categorical variable.
    """
    categorical_columns = df.select_dtypes(include=['object']).columns
    for col in categorical_columns:
        plt.figure(figsize=(10, 6))
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.xticks(rotation=45, ha='right')
        plt.show()

# Plot categorical distributions
plot_categorical_distributions(df)

categorical_columns = df.select_dtypes(include=['object']).columns  # Only categorical columns

for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[col], y=df['price'])
    plt.xticks(rotation=45, ha='right')
    plt.title(f"Price Distribution by {col}")
    plt.show()
# Out:
# For id, 23947 unique values present
# For price, 4224 unique values present
# For property_type, 1 unique values present
# For subproperty_type, 1 unique values present
# For region, 3 unique values present
# For province, 11 unique values present
# For locality, 43 unique values present
# For zip_code, 1046 unique values present
# For latitude, 19282 unique values present
# For longitude, 19291 unique values present
# For construction_year, 184 unique values present
# For total_area_sqm, 533 unique values present
# For surface_land_sqm, 2616 unique values present
# For nbr_frontages, 12 unique values present
# For nbr_bedrooms, 23 unique values present
# For equipped_kitchen, 9 unique values present
# For fl_furnished, 2 unique values present
# For fl_open_fire, 2 unique values present
# For fl_terrace, 2 unique values present
# For terrace_sqm, 153 unique values present
# For fl_garden, 2 unique values present
# For garden_sqm, 1130 unique values present
# ...

# %%
# Out:
# Best alpha for Ridge Regression: {'model__alpha': 1}
