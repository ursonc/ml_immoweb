# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('properties.csv')

# Step 2: Drop rows without a price
df.dropna(subset=['price'], inplace=True)
missing_data_summary = df.isnull().sum()
missing_columns = missing_data_summary[missing_data_summary > 0]
print(missing_data_summary)


# Sort column names alphabetically and print
sorted_columns = sorted(df.columns)
print("\nAlphabetically Sorted Columns:")
print(sorted_columns)

categorical_columns = df.select_dtypes(include=['object', 'category']).columns
# Out:
# id                                    0
# price                                 0
# property_type                         0
# subproperty_type                      0
# region                                0
# province                              0
# locality                              0
# zip_code                              0
# latitude                          14098
# longitude                         14098
# construction_year                 33391
# total_area_sqm                     7615
# surface_land_sqm                  36256
# nbr_frontages                     26346
# nbr_bedrooms                          0
# equipped_kitchen                      0
# fl_furnished                          0
# fl_open_fire                          0
# fl_terrace                            0
# terrace_sqm                       13140
# fl_garden                             0
# garden_sqm                         2939
# fl_swimming_pool                      0
# ...

# %%
# Number of rows in the original DataFrame
original_count = len(df)

# Number of rows in the filtered DataFrame
filtered_count = len(house_sqm_no_outliers)

# Calculate the number of outliers removed
outliers_removed = original_count - filtered_count

print(f"Number of outliers removed: {outliers_removed}")
print(f"Original row count: {original_count}")
print(f"Filtered row count: {filtered_count}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 original_count = len(df)
#       4 # Number of rows in the filtered DataFrame
# ----> 5 filtered_count = len(house_sqm_no_outliers)
#       7 # Calculate the number of outliers removed
#       8 outliers_removed = original_count - filtered_count
#
# NameError: name 'house_sqm_no_outliers' is not defined

# %%
# Summary statistics for numerical columns
print("Summary statistics for numerical columns:\n", df.describe())

# Summary for categorical columns
print("\nSummary for categorical columns:\n", df.describe(include=['object']))
# Out:
# Summary statistics for numerical columns:
#                   id          price      zip_code      latitude     longitude  \
# count  2.179700e+04   21797.000000  21797.000000  17918.000000  17918.000000
# mean   3.979173e+07  332261.962839   5364.360279     50.816694      4.498776
# std    2.291270e+07  136796.130451   2764.130972      0.433076      1.184927
# min    9.000000e+03   77500.000000   1000.000000     25.761680    -80.191790
# 25%    1.995200e+07  229000.000000   2650.000000     50.618893      3.983767
# 50%    3.978100e+07  325000.000000   5002.000000     50.862302      4.454897
# 75%    5.975300e+07  419000.000000   7880.000000     51.086054      5.130026
# max    7.948500e+07  736221.000000   9990.000000     52.434244      6.385048
#
#        construction_year  total_area_sqm  surface_land_sqm  nbr_frontages  \
# count       11660.000000    19273.000000      21797.000000   21797.000000
# mean         1968.703345      177.745084        622.113961       2.875396
# ...

# %%
df.head()
# Out:
#          id     price property_type subproperty_type    region  \
# 0   2104000  449000.0         HOUSE            HOUSE  Flanders
# 1  58496000  501000.0         HOUSE            HOUSE  Flanders
# 2  22183000  548514.0         HOUSE            HOUSE  Flanders
# 3  48707000  424000.0         HOUSE            HOUSE  Flanders
# 4  28322000  385000.0         HOUSE            HOUSE  Flanders
#
#           province         locality  zip_code   latitude  longitude  ...  \
# 0    East Flanders             Gent      9185  51.174944   3.845248  ...
# 1          Antwerp         Turnhout      2275  51.238312   4.817192  ...
# 2  Flemish Brabant  Halle-Vilvoorde      1700        NaN        NaN  ...
# 3    East Flanders             Gent      9800  50.983015   3.570742  ...
# 4    East Flanders     Sint-Niklaas      9190  51.206244   4.075700  ...
#
#    fl_garden  garden_sqm  fl_swimming_pool  fl_floodzone  state_building  \
# ...

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# id                              28397.0  3.969425e+07  2.297458e+07
# price                           28397.0  3.454190e+05  1.438170e+05
# zip_code                        28397.0  5.655049e+03  2.843091e+03
# latitude                        23032.0  5.083476e+01  4.065966e-01
# longitude                       23032.0  4.408529e+00  1.124781e+00
# construction_year               14339.0  1.971275e+03  4.483706e+01
# total_area_sqm                  24478.0  1.790802e+02  1.566594e+02
# surface_land_sqm                28397.0  6.141608e+02  2.338702e+03
# nbr_frontages                   22184.0  2.884466e+00  8.669004e-01
# nbr_bedrooms                    28397.0  3.247702e+00  1.097765e+00
# fl_furnished                    28397.0  7.183857e-03  8.445413e-02
# fl_open_fire                    28397.0  1.897384e-01  3.921009e-01
# fl_terrace                      28397.0  4.670212e-01  4.989200e-01
# ...

# %%
# Distribution of 'price'
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True, bins=30)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()


categorical_columns = df.select_dtypes(include=['object']).columns  # Only categorical columns

for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[col], y=df['price'])
    plt.xticks(rotation=45, ha='right')
    plt.title(f"Price Distribution by {col}")
    plt.show()

# %%
# Missing data summary
missing_data_summary = df.isnull().sum()
missing_columns = missing_data_summary[missing_data_summary > 0]
print("Missing data per column:\n", missing_columns)
# DataFrame info
df.info()
# Out:
# Missing data per column:
#  latitude                           4241
# longitude                          4241
# construction_year                 10431
# total_area_sqm                     2574
# terrace_sqm                        6228
# garden_sqm                         1731
# primary_energy_consumption_sqm     6028
# cadastral_income                   9827
# price_per_square_meter             2574
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22868 entries, 0 to 22867
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22868 non-null  int64
#  1   price                           22868 non-null  float64
#  2   property_type                   22868 non-null  object
#  3   subproperty_type                22868 non-null  object
#  4   region                          22868 non-null  object
# ...
